# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import Tasks
import Main
import Hyperparameters as hp
import Visualisation_helpers

# %%
# Visualise the results
fig, ax = Visualisation_helpers.plot_sample_trial((1,2,0))
fig.show()
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_27348\1799470983.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
my_model = Main.Net()
loss_function = nn.MSELoss()
optimizer = optim.Adam(my_model.parameters(), lr=hp.get_training_params()['lr'])

# %%
losses = Main.train_network(my_model, optimizer, loss_function) # Train the network
# Out:
# ...
# 100%|██████████| 1000/1000 [04:46<00:00,  3.49it/s]

# %%
fig, ax = Visualisation_helpers.plot_loss_curve(losses)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\edwar\Documents\SpatialModules\Testing_notebook.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/edwar/Documents/SpatialModules/Testing_notebook.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = Visualisation_helpers.plot_loss_curve(losses)
#       <a href='vscode-notebook-cell:/c%3A/Users/edwar/Documents/SpatialModules/Testing_notebook.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# NameError: name 'losses' is not defined

# %%
fig, ax = Visualisation_helpers.plot_smoothed_loss_curve(losses)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\edwar\Documents\SpatialModules\Testing_notebook.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/edwar/Documents/SpatialModules/Testing_notebook.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = Visualisation_helpers.plot_smoothed_loss_curve(losses)
#       <a href='vscode-notebook-cell:/c%3A/Users/edwar/Documents/SpatialModules/Testing_notebook.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# NameError: name 'losses' is not defined

# %%
fig, ax = Visualisation_helpers.discrepancy_visualisation((0,0,0), my_model)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\edwar\Documents\SpatialModules\Testing_notebook.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/edwar/Documents/SpatialModules/Testing_notebook.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = Visualisation_helpers.discrepancy_visualisation((0,0,0), my_model)
#       <a href='vscode-notebook-cell:/c%3A/Users/edwar/Documents/SpatialModules/Testing_notebook.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# NameError: name 'my_model' is not defined

# %%
fig, ax = Visualisation_helpers.cosine_visualisation((1,0,1), my_model)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\edwar\Documents\SpatialModules\Testing_notebook.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/edwar/Documents/SpatialModules/Testing_notebook.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = Visualisation_helpers.cosine_visualisation((1,0,1), my_model)
#       <a href='vscode-notebook-cell:/c%3A/Users/edwar/Documents/SpatialModules/Testing_notebook.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# NameError: name 'my_model' is not defined

# %%
Main.save_training_run(my_model, losses)
